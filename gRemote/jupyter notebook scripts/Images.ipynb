# %% [markdown]
# ## 灰白 Aws multi-client fps. 柱状图

# %%
import matplotlib
matplotlib.rcParams['font.family'] = "Linux Libertine O"
matplotlib.rcParams['text.usetex'] = True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# import matplotlib

# matplotlib.font_manager._rebuild()

plt.figure(figsize=(13,4))


titleFont = {'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
    }

font1 = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
}

font2 = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 13
}
labelFont = {'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 24
    }

xyticksFont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
}

color4 = "#000000"
color2 = "r"
color8 = "#0065DD"
color6 = "#BBBBBB"
color1 = "#505050"
# color8 = "#00B06F"
color10 = "#E0E0E0"

# stars	glxgears	blender	dinoshade	scube	spot	surfgrid	drawelements
program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
N = 8
hist_data = {}
width = 0.38
x = np.arange(1,3*N+1,3) - 3 * width
for name in program_names:
    tmp_data = pd.read_excel('aws-fps-记录-new.xlsx',name).iloc[0:250]
    hist_data[name] = tmp_data.mean()[0:6]
hist_data = pd.DataFrame(hist_data).T
hist_data = hist_data.reindex(program_names)
plt.axhline(y=60,color='#777777',linestyle='--',linewidth=2)
plt.axhline(y=30,color='#777777',linestyle='--',linewidth=2)

plt.bar(x,hist_data.iloc[:,0],width,edgecolor="black",facecolor=color1,color=color1,hatch="///",label="1 client")
plt.bar(x+width,hist_data.iloc[:,1],width,edgecolor="black",hatch="...", color=color2,label="2 clients")
plt.bar(x+2 * width,hist_data.iloc[:,2],width,edgecolor="black",color=color4,label="4 clients")
plt.bar(x+3 * width,hist_data.iloc[:,3],width,edgecolor="black",hatch="\\\\\\",color=color6,label="6 clients")
plt.bar(x+4 * width,hist_data.iloc[:,4],width,edgecolor="black",facecolor=color8,hatch="",color=color8,label="8 clients")
plt.bar(x+5 * width,hist_data.iloc[:,5],width,edgecolor="black",facecolor="none",color=color10,label="10 clients")

# plt.title("Fps",font)
plt.xticks(np.arange(1,3*N+1,3) - width / 2,program_names,rotation=0,fontname=font1['family'],fontsize=16)
plt.yticks(np.arange(0,90,10),fontname=font1['family'],fontsize=16)
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.ylabel("FPS",labelFont)
plt.legend(bbox_to_anchor=(0.9, 0.5, 2.25, .12), loc='lower left',prop=font2)
plt.tight_layout()
# plt.savefig("/home/yinlan/Desktop/paper/img/fig6_aws-client.pdf")
# Out:
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:73: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# findfont: Font family ['Linux Libertine O'] not found. Falling back to DejaVu Sans.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))


titleFont = {'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
    }


labelFont = {'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 18
    }

xyticksFont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
}

color4 = "#000000"
color2 = "r"
color8 = "#0065DD"
color6 = "#BBBBBB"
color1 = "#505050"
# color8 = "#00B06F"
color10 = "#E0E0E0"

# stars	glxgears	blender	dinoshade	scube	spot	surfgrid	drawelements
program_names = ['blender','dinoshade','scube','spot','glxgears']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
N = 5
# hist_data = {}
width = 0.38
x = np.arange(1,3*N+1,3) - 2 * width
# for name in program_names:
#     tmp_data = pd.read_excel('aws-fps-记录-new.xlsx',name).iloc[0:250]
#     hist_data[name] = tmp_data.mean()[0:6]
hist_data = pd.read_excel("all fps.xlsx","motivation_fps") * 100
# hist_data = pd.DataFrame(hist_data).T
hist_data = hist_data.reindex(program_names)
# plt.axhline(y=60,color='#777777',linestyle='--',linewidth=2)
# plt.axhline(y=30,color='#777777',linestyle='--',linewidth=2)

plt.bar(x,hist_data.iloc[:,0],width,edgecolor="black",facecolor=color1,color=color1,hatch="///",label="1 client")
plt.bar(x+width,hist_data.iloc[:,1],width,edgecolor="black",hatch="...", facecolor="red",color=color2,label="2 clients")
plt.bar(x+2 * width,hist_data.iloc[:,2],width,edgecolor="black",color=color4,label="4 clients")
# plt.bar(x+3 * width,hist_data.iloc[:,3],width,edgecolor="black",hatch="\\\\\\",color=color6,label="6 clients")
# plt.bar(x+4 * width,hist_data.iloc[:,4],width,edgecolor="black",facecolor=color8,hatch="",color=color8,label="8 clients")
# plt.bar(x+5 * width,hist_data.iloc[:,5],width,edgecolor="black",facecolor="none",color=color10,label="10 clients")

# plt.title("Fps",font)
plt.xticks(np.arange(1,3*N+1,3) - width / 2,program_names,rotation=0,fontname=font1['family'],fontsize=16)
plt.yticks(np.arange(0,101,10),fontname=font1['family'],fontsize=16)
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.ylabel("FPS (% of one client)",labelFont)
plt.legend(bbox_to_anchor=(0.25, 1.0, 2.25, .12), ncol=4,loc='lower left', prop=font2)
plt.tight_layout()
# plt.savefig("/home/yinlan/Desktop/raw_client_fps.pdf")
# Out:
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:59: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))


titleFont = {'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
    }


labelFont = {'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 18
    }

xyticksFont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 16
}

color4 = "#000000"
color2 = "r"
color8 = "#0065DD"
color6 = "#BBBBBB"
color1 = "#505050"
# color8 = "#00B06F"
color10 = "#E0E0E0"

# stars	glxgears	blender	dinoshade	scube	spot	surfgrid	drawelements
program_names = ['blender','dinoshade','scube','spot','glxgears']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
N = 5
# hist_data = {}
width = 0.38
x = np.arange(1,3*N+1,3) - 2 * width
# for name in program_names:
#     tmp_data = pd.read_excel('aws-fps-记录-new.xlsx',name).iloc[0:250]
#     hist_data[name] = tmp_data.mean()[0:6]
hist_data = pd.read_excel("all fps.xlsx","motivation_gpu")
# hist_data = pd.DataFrame(hist_data).T
hist_data = hist_data.reindex(program_names)
# plt.axhline(y=100,color='black',linestyle='--',linewidth=1)
# plt.axhline(y=30,color='#777777',linestyle='--',linewidth=2)

plt.bar(x,hist_data.iloc[:,0],width,edgecolor="black",facecolor=color1,color=color1,hatch="///",label="1 client")
plt.bar(x+width,hist_data.iloc[:,1],width,edgecolor="black",hatch="...", facecolor="red",color=color2,label="2 clients")
plt.bar(x+2 * width,hist_data.iloc[:,2],width,edgecolor="black",color=color4,label="4 clients")
# plt.bar(x+3 * width,hist_data.iloc[:,3],width,edgecolor="black",hatch="\\\\\\",color=color6,label="6 clients")
# plt.bar(x+4 * width,hist_data.iloc[:,4],width,edgecolor="black",facecolor=color8,hatch="",color=color8,label="8 clients")
# plt.bar(x+5 * width,hist_data.iloc[:,5],width,edgecolor="black",facecolor="none",color=color10,label="10 clients")

# plt.title("Fps",font)
plt.xticks(np.arange(1,3*N+1,3) - width / 2,program_names,rotation=0,fontname=font1['family'],fontsize=16)
plt.yticks(np.arange(0,101,10),fontname=font1['family'],fontsize=16)
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.ylabel("GPU resource usage(%)",labelFont)
plt.legend(bbox_to_anchor=(0.24, 1.0, 2.25, .12), ncol=4,loc='lower left', prop=font2)
plt.tight_layout()
# plt.savefig("/home/yinlan/Desktop/raw_client_gpu.pdf")
# Out:
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:59: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
hist_data

# %%
pd.read_excel("all fps.xlsx","motivation_fps")

# %%
hist_data
hist_data = hist_data.reindex(program_names)
hist_data.iloc[0]

# %% [markdown]
# ## gRemote FPS and CPU 图

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#gRemote / 4 CPUs
fps1 = pd.read_excel("all fps.xlsx","fps_raw") / 4
# pd.read_excel("all fps.xlsx","fps_between_30_40")
#gRemote without Throttle / 4 CPUs 
fps2 = pd.read_excel("all fps.xlsx","fps_between_60_80") / 4
# fps3 = pd.read_excel("all fps.xlsx","fps_raw")
# Baseline
fps3 = np.asarray([43.6,59.6,63.9,57.9,60.6,51.3,75.1,34.8])
plt.figure(figsize=(13,8))
N = 8
width = 0.25       # the width of the bars: can also be len(x) sequence
ind1 = np.arange(N) - width    # the x locations for the groups
ind2 = np.arange(N)
ind3 = np.arange(N) + width

color1 = "#000000"
color2 = "r"
color3 = "#B0B0B0"
color4 = "#0065DD"
labelfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 21
}

ticksfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 16
}
plt.bar(ind1,fps3,width,facecolor="#000000",label="gRemote without optimization",edgecolor="black")
plt.bar(ind2,fps1.mean(),  width,hatch='',facecolor=color2,label="gRemote without Throttle",edgecolor="black")
plt.bar(ind3,fps2.mean(), width,hatch='', facecolor=color3,label="gRemote",edgecolor="black")

program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
plt.xticks(ind2, program_names,rotation=45,fontname=ticksfont['family'],fontsize=25)
plt.yticks(np.arange(0,81,20),fontsize=25)
# plt.title('CPU Utilization',font)
plt.ylabel('Utilization(%)',fontsize=25)
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc="upper left",frameon=False,bbox_to_anchor=(0.0, 0.95, .75, .12),ncol=3,fontsize=18)
plt.tight_layout()
plt.savefig("/home/yinlan/Desktop/fig13_CPUutilization.pdf")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#gRemote / 4 CPUs
fps1 = pd.read_excel("all fps.xlsx","fps_raw") / 4
# pd.read_excel("all fps.xlsx","fps_between_30_40")
#gRemote without Throttle / 4 CPUs 
fps2 = pd.read_excel("all fps.xlsx","fps_between_60_80") / 4
# fps3 = pd.read_excel("all fps.xlsx","fps_raw")
# Baseline
fps3 = np.asarray([43.6,59.6,63.9,57.9,60.6,51.3,75.1,34.8])
# fig = plt.figure(figsize=(13,8))
fig = plt.figure(figsize=(13,8))
ax1 = fig.add_subplot(111)
N = 8
width = 0.25       # the width of the bars: can also be len(x) sequence
ind1 = np.arange(N) - width    # the x locations for the groups
ind2 = np.arange(N)
ind3 = np.arange(N) + width

color1 = "#000000"
color2 = "r"
color3 = "#B0B0B0"
color4 = "#0065DD"
labelfont = {'family' : 'Linux Libertine Bold',
'weight' : 'normal',
'fontsize'   : 26
}

ticksfont = {'family' : 'Linux Libertine Bold',
'weight' : 'normal',
'size'   : 16
}
ax1.bar(ind1,fps3,width,facecolor="#000000",label="Baseline",edgecolor="black")
ax1.bar(ind2,fps1.mean(),  width,hatch='',facecolor=color2,label="gRemote without Throttle",edgecolor="black")
ax1.bar(ind3,fps2.mean(), width,hatch='', facecolor=color3,label="gRemote",edgecolor="black")

program_names = ['blender', 'blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
ax1.set_xticks(ind2, program_names)
ax1.set_yticks(np.arange(0,91,10))
ax1.set_yticklabels(np.arange(0,91,10),fontsize=19)
# plt.title('CPU Utilization',font)
ax1.legend(bbox_to_anchor=(0.0, 1, .93, .12), fontsize=18,loc='lower left',ncol=2, mode="expand", borderaxespad=0.,frameon=False)
ax1.set_xticklabels(program_names, fontdict=labelFont,rotation = 45)
ax2 = ax1.twinx()
gpuUtili = np.asarray([27.65,24.60,20.70,21.50,25.90,27.98,27.50,22.33])
ax2.plot(ind2,gpuUtili,marker='s',linestyle='--',markerfacecolor='none',markersize=8,label="GPU Utilization",linewidth=2,color="#0065DD")
ax2.set_yticks(np.arange(0,36,5))
ax2.set_yticklabels(np.arange(0,36,5),fontsize=19)
ax2.set_ylabel("GPU Utilization(%)",fontsize=21)
ax2.legend(bbox_to_anchor=(-0.01, 0.95, 1.0, .12),fontsize=18,loc='upper right',borderaxespad=0.,frameon=False)

ax1.set_ylabel('Utilization(%)',fontsize=21)
ax2.set_xticklabels(program_names, fontdict=labelFont,rotation = 45)
# plt.xticks(ind2, program_names, fontsize=25, fontname=ticksfont["family"])


# ax = plt.axes()
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# plt.legend(loc="upper left",frameon=False,bbox_to_anchor=(0.0, 0.95, .75, .12),ncol=3,fontsize=18)
plt.tight_layout()
plt.savefig("/home/yinlan/Desktop/fig13_CPUutilization.pdf")

# %%
# ?ax2.set_xticklabels

# %%
plt.figure(figsize=(11,8))
data = pd.read_excel("all fps.xlsx","rdma_ffmpeg_cpu") / 4
N = 8
width = 0.25       # the width of the bars: can also be len(x) sequence
ind1 = np.arange(N) - width    # the x locations for the groups
ind2 = np.arange(N)
ind3 = np.arange(N) + width

color1 = "#000000"
color2 = "#DD0000"
color3 = "#B0B0B0"
color4 = "b"


labelfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 30
}

ticksfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 20
}


# plt.bar(ind1,data.loc["cgl"], width,facecolor="#303030",hatch='//',label="gRemote(TCP/IP) Rendering",edgecolor="#000000")
plt.bar(ind3,data.loc["rdma/bmp"], width,facecolor="#B0B0B0",label="gRemote(RDMA/bmp)",edgecolor="black")
plt.bar(ind1,data.loc["port"] + data.loc["cgl"], width,facecolor="#000000",hatch="",label="gRemote(Ethernet) with ffmpeg",edgecolor="black")
plt.bar(ind2,data.loc["rdma/webp"], width,facecolor=color2,label="gRemote(RDMA/webp)",edgecolor="black")

program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
plt.xticks(ind2, program_names,rotation=45,fontname=ticksfont["family"],fontsize=25)
plt.yticks(np.arange(0,150,10),fontname=ticksfont["family"],fontsize=ticksfont['size'])
# plt.title('CPU Utilization',font)
plt.ylabel('Utilization(%)',labelfont)
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc="upper left",ncol=2,fontsize=20,frameon=False,bbox_to_anchor=(-0.01, 0.9, 2.25, .12))
plt.tight_layout()
plt.savefig("/home/yinlan/Desktop/fig16_rdma.pdf",bbox_to_anchor="tight")

# %%
networkdata = pd.read_excel("network.xlsx","network_12_11")
mean = networkdata.describe().loc['mean'] / 1000

plt.figure(figsize=(10.5,8))
N = 8
net0mask = np.arange(0,14,2)
net3mask = np.arange(1,16,2)
width = 0.25       # the width of the bars: can also be len(x) sequence
ind = np.arange(N) - 2 * width   # the x locations for the groups
ind2 = ind + width

color1 = "#000000"
color2 = "r"
color3 = "#B0B0B0"
color4 = "#B0B0B0"
net0mean = np.hstack(((mean.iloc[net0mask]),mean.iloc[14]))
p1 = plt.bar(ind, net0mean, width, label="gRemote without\nCCO Compression",color=color1,edgecolor="black")
p2 = plt.bar(ind2, mean.iloc[net3mask],width, hatch='',label="gRemote with\nCCO Compression",color=color2,edgecolor="black")
aws_networkdata = pd.read_excel("network.xlsx","network_aws")
mean_aws = aws_networkdata.describe().loc['mean'] / 1000 / 1000
ind3 = ind2 + width
p3 = plt.bar(ind3,mean_aws,width,hatch='',color = color4,label="Amazon\nElastic GPU",edgecolor="black")

ffplay_networkdata = pd.read_excel("network.xlsx","ffplay")
mean_ffplay = ffplay_networkdata.describe().loc['mean'] / 1000
ind4 = ind3 + width
labelfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 21
}

ticksfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 16
}
program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
xtic = np.arange(N-1) - width
xtic = xtic.tolist()
xtic.append(N-1 - width)
plt.xticks(xtic, program_names,rotation=45,fontname=ticksfont['family'],fontsize=21)
# plt.yticks(np.hstack(([0,5],np.arange(10,35,5))),[0,5,75,80,85,90,95],fontname=ticksfont['family'],fontsize=19)
# plt.yticks(np.arange(0,60,20))
plt.ylabel('Bandwidth(MiB/s)',labelfont)
plt.tight_layout()
plt.legend("upper right")
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
lgd = plt.legend(loc="upper left",frameon=False,bbox_to_anchor=(0.015, 0.94, 2.25, .12),fontsize=17,ncol=3,labelspacing=0.)
# plt.savefig("/home/yinlan/Desktop/fig9_network command stream.pdf",bbox_extra_artists=(lgd,),bbox_to_anchor="tight")

# %%
networkdata = pd.read_excel("network.xlsx","network_12_11")
mean = networkdata.mean() / 1000

plt.figure(figsize=(10.5,7))
N = 8
net0mask = np.arange(0,24,3)
net1mask = np.arange(1,24,3)
net3mask = np.arange(2,24,3)
width = 0.25       # the width of the bars: can also be len(x) sequence
ind0 = np.arange(N) - 2 * width   # the x locations for the groups
ind1 = ind0 + width
ind2 = ind0 + width * 2

color1 = "#000000"
color2 = "r"
color3 = "#B0B0B0"
color4 = "#B0B0B0"
p1 = plt.bar(ind0, mean.iloc[net0mask], width, label="gRemote without\noptimization",color=color1,edgecolor="black")
p2 = plt.bar(ind1, mean.iloc[net1mask], width, hatch='',label="gRemote with LZ77\nCompression",color=color2,edgecolor="black")
p3 = plt.bar(ind2, mean.iloc[net3mask], width, hatch='',color = color4,label="gRemote with\nCCO Compression",edgecolor="black")
# net0mean = np.hstack(((mean.iloc[net0mask] - 60),mean.iloc[14]))
# p1 = plt.bar(ind, net0mean, width, label="gRemote without\nCCO Compression",color=color1,edgecolor="black")
# p2 = plt.bar(ind2, mean.iloc[net3mask],width, hatch='',label="gRemote with\nCCO Compression",color=color2,edgecolor="black")
# aws_networkdata = pd.read_excel("network.xlsx","network_aws")
# mean_aws = aws_networkdata.describe().loc['mean'] / 1000 / 1000
# ind3 = ind2 + width
# p3 = plt.bar(ind3,mean_aws,width,hatch='',color = color4,label="Amazon\nElastic GPU",edgecolor="black")

# ffplay_networkdata = pd.read_excel("network.xlsx","ffplay")
# mean_ffplay = ffplay_networkdata.describe().loc['mean'] / 1000
# ind4 = ind3 + width
labelfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 21
}

ticksfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 16
}
program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
xtic = np.arange(N-1) - width
xtic = xtic.tolist()
xtic.append(N-1 - width)
plt.xticks(xtic, program_names,rotation=45,fontname=ticksfont['family'],fontsize=21)
plt.yticks([0,2,5,10,20,30,40],fontname=ticksfont['family'],fontsize=19)
# plt.yticks(np.arange(0,60,20))
plt.ylabel('Bandwidth(MiB/s)',labelfont)
plt.tight_layout()
plt.legend("upper right")
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
lgd = plt.legend(loc="upper left",frameon=False,bbox_to_anchor=(0.005, 1., 2.25, .12),fontsize=17,ncol=3,labelspacing=0.)
plt.tight_layout()
plt.savefig("/home/yinlan/Desktop/network.pdf",bbox_extra_artists=(lgd,),bbox_to_anchor="tight")

# %%
networkdata = pd.read_excel("network.xlsx","network_12_11")
mean = networkdata.mean() / 1000

plt.figure(figsize=(10.5,7))
N = 8
net0mask = np.arange(0,24,3)
net1mask = np.arange(1,24,3)
net3mask = np.arange(2,24,3)
width = 0.25       # the width of the bars: can also be len(x) sequence
ind0 = np.arange(N) - 2 * width   # the x locations for the groups
ind1 = ind0 + width
ind2 = ind0 + width * 2

color1 = "#000000"
color2 = "r"
color3 = "#B0B0B0"
color4 = "#B0B0B0"
# p1 = plt.bar(ind0, mean.iloc[net0mask], width, label="Baseline",color=color1,edgecolor="black")
p2 = plt.bar(ind1, mean.iloc[net1mask], width, hatch='',label="gRemote with LZ77 Compression",color=color1,edgecolor="black")
p3 = plt.bar(ind2, mean.iloc[net3mask], width, hatch='',color = color2,label="gRemote with CCO Compression",edgecolor="black")
# net0mean = np.hstack(((mean.iloc[net0mask] - 60),mean.iloc[14]))
# p1 = plt.bar(ind, net0mean, width, label="gRemote without\nCCO Compression",color=color1,edgecolor="black")
# p2 = plt.bar(ind2, mean.iloc[net3mask],width, hatch='',label="gRemote with\nCCO Compression",color=color2,edgecolor="black")
# aws_networkdata = pd.read_excel("network.xlsx","network_aws")
# mean_aws = aws_networkdata.describe().loc['mean'] / 1000 / 1000
# ind3 = ind2 + width
# p3 = plt.bar(ind3,mean_aws,width,hatch='',color = color4,label="Amazon\nElastic GPU",edgecolor="black")

# ffplay_networkdata = pd.read_excel("network.xlsx","ffplay")
# mean_ffplay = ffplay_networkdata.describe().loc['mean'] / 1000
# ind4 = ind3 + width
labelfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 21
}

ticksfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 16
}
program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
xtic = np.arange(N-1) - width
xtic = xtic.tolist()
xtic.append(N-1 - width)
plt.xticks(xtic, program_names,rotation=45,fontname=ticksfont['family'],fontsize=21)
plt.yticks(np.arange(0,2.0,0.2),fontname=ticksfont['family'],fontsize=21)
# plt.yticks(np.arange(0,60,20))
plt.ylabel('Bandwidth(MiB/s)',labelfont)
plt.tight_layout()
plt.legend("upper right")
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
lgd = plt.legend(loc="upper left",frameon=False,bbox_to_anchor=(0.02, 0.94, 2.25, .12),fontsize=17,ncol=1,labelspacing=1)
plt.savefig("/home/yinlan/Desktop/network_withoutnative.pdf",bbox_extra_artists=(lgd,),bbox_to_anchor="tight")

# %%
mean

# %%
net0mean 
mean

# %%
plt.figure(figsize=(10.5,8))
N = 8
width = 0.25       # the width of the bars: can also be len(x) sequence
ind = np.arange(N) - 2 * width   # the x locations for the groups
ind2 = ind + width

color1 = "#000000"
color2 = "r"
color3 = "#B0B0B0"
color4 = "#B0B0B0"


ind4 = ind2 - width
ind3 = ind2 + width

raw_video_stream = [59.15169792,66.67743744,70.0535808,64.17865728,67.34052864,62.29928448,64.51241472,53.48077056]
raw_video_stream = (np.array(raw_video_stream) - 30) / 5
p3 = plt.bar(ind4,raw_video_stream,width,label="gRemote without\nFFmpeg",color=color1,edgecolor="black")
# [TODO]

ffplay_networkdata = pd.read_excel("network.xlsx","ffplay")
mean_ffplay = ffplay_networkdata.describe().loc['mean'] / 1000
p1 = plt.bar(ind2,mean_ffplay,width,label="gRemote with\nFFmpeg",hatch='',color=color2,edgecolor="black")


aws_video_stream = pd.read_excel("network.xlsx","aws_download")
mean_aws_video_stream = aws_video_stream.describe().loc['mean'] / 1000 / 1000
p2 = plt.bar(ind3,mean_aws_video_stream,width,label="Amazon\nElastic GPU",hatch='',color=color4,edgecolor="black")

labelfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 21
}

ticksfont = {'family' : 'Linux Libertine O',
'weight' : 'normal',
'size'   : 16
}
program_names = ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
# program_names =  ['stars','glxgears','blender','dinoshade','scube','spot','surfgrid','drawelements']
plt.xticks(np.arange(N) - width, program_names,rotation=45,fontname=ticksfont['family'],fontsize=21)
plt.yticks([0,2.5,4,6,8,10],[0,2.5,50,60,70,80],fontsize=19)
plt.ylabel('Bandwidth(MiB/s)',labelfont)
plt.legend(loc = "upper left",fontsize=19,ncol=3,frameon=False,bbox_to_anchor=(-0.0, 0.9, 2.25, .12))
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
# plt.savefig("/home/yinlan/Desktop/paper/img/fig8_network video stream.pdf")

# %%
mean_aws_video_stream

# %% [markdown]
# ## GPU Scheduler

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# plt.figure(figsize=(8,3))

average_gpu_utilization = [63.175,27.54,0.12,47.91,47.415,47.78]
font1 = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 15
}
GPUNUM = 2
width = 0.2
color1 = "#BBBBBB"
color2 = "r"
color3 = "#505050"
color4 = "b"
#10apps,2apps,0apps,4apps,4apps,4apps
# plt.bar(index1,gpu1,width,color=color1,label="GPU-1")
# plt.bar(index2,gpu2,width,color=color2,label="GPU-2")
# plt.bar(index3,gpu3,width,color=color3,label="GPU-3")
# plt.xticks(np.arange(1,3))

fig = plt.figure()
ax1 = fig.add_subplot(111) 
gremote_with_scheduler = [63.175,27.54,0.2]
gremote_without_scheduler = [47.91,47.415,47.78]
index_with_scheduler = np.arange(1,4) - width /2
index_without_scheduler = np.arange(1,4) + width /2

ax1.bar(index_with_scheduler,gremote_with_scheduler,width,facecolor=color3,edgecolor="black",label="Negotiation-Oriented Scheduler")
ax1.bar(index_without_scheduler,gremote_without_scheduler,width,color=color1,edgecolor="black",label="Baseline")
ax1.set_xticks(np.arange(1,4),["GPU-1","GPU-2","GPU-3"])
ax1.set_yticks(np.arange(0,71,10))
ax1.set_ylabel("GPU Utilization(%)\n-bar graph",font1)
plt.legend(bbox_to_anchor=(0.0, 1.1, 1.0, .12), fontsize=11,loc='lower left',ncol=2, mode="expand", borderaxespad=0.,frameon=False)


ax2 = ax1.twinx()
gremote_with_scheduler = [30,6,0.1]
gremote_without_scheduler = [12,12,12]
index_with_scheduler = np.arange(1,4)
index_without_scheduler = np.arange(1,4)
ax2.plot(index_with_scheduler,gremote_with_scheduler,marker='s',linestyle='--',markerfacecolor='none',markersize=8,label="Negotiation-Oriented Scheduler",linewidth=2,color="#0065DD")
ax2.plot(index_without_scheduler,gremote_without_scheduler,marker='^',linestyle='--',markerfacecolor='none',markersize=8,label="Baseline",linewidth=2,color="r")
ax2.set_ylabel("Application Number\n-line graph",font1)
ax2.set_xticks(np.arange(1,4),["GPU-1","GPU-2","GPU-3"])
plt.tight_layout()
plt.legend(bbox_to_anchor=(0.0, 1.03, 1.0, .12), fontsize=11,loc='lower right',ncol=2, mode="expand", borderaxespad=0.,frameon=False)

plt.xticks(np.arange(1,4),["GPU-1","GPU-2","GPU-3"])

# plt.savefig("/home/yinlan/Desktop/paper/img/fig10_GPU.pdf",bbox_inches = 'tight')

# %%
# ?plt.text()

# %% [markdown]
# ## gRemote Fps line

# %% [markdown]
# ## Aws fps line

# %%
# filenames = ["glxgears_1.log_out","glxgears_10.log_out","glxgears_20.log_out","glxgears_30.log_out","glxgears_40.log_out"]
# PATH = "fps/4_11/"
# xtickNames = ["1","10","20","30","40"]

# font1 = {
#     'family' : 'Linux Libertine O',
#     'weight' : 'normal',
#     'size'   : 16
# }

# font2 = {
#     'family' : 'Linux Libertine O',
#     'weight' : 'normal',
#     'size'   : 13
# }
# colors = ["#505050","r","#000000","#0065DD","#BBBBBB"]
# N = 150
# fig,ax = plt.subplots(1,1)
# for i in range(0,5):
#     df = pd.read_csv(PATH+filenames[i],header=None)
#     ax.plot(np.arange(1 + (i) * N,(i + 1) * N + 1),df.iloc[0:N],color=colors[i])
#     ax.set_yticks(np.arange(28,45,2))
# #     ax.grid(linestyle='--')

# plt.xlabel("Number of Clients(glxgears)",font2)
# plt.ylabel("FPS of Applications",font1)
# for l in np.arange(0,900,150):
#     plt.axvline(x=l,color='#A0A0A0',ls='--',linewidth=1)
# plt.axhline(y=40,color="black",ls='--')
# plt.axhline(y=30,color="black",ls='--')
# plt.xticks(np.arange(75,800,150),xtickNames,rotation=0)
# plt.savefig("/home/yinlan/Desktop/paper/img/scal.pdf")

# %%
filenames = ["glxgears_1.log_out","glxgears_10.log_out","glxgears_20.log_out","glxgears_30.log_out","glxgears_40.log_out"]
PATH = "fps/4_11/"
xtickNames = ["1","10","20","30","40"]

labelFont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 18
}

font2 = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 13
}
colors = ["#505050","r","#000000","#0065DD","#BBBBBB"]
N = 150
fig,ax = plt.subplots(1,1)
fig.set_figheight(4)
fig.set_figwidth(6)
data = []
BEGIN = 28
for i in range(0,5):
    df = pd.read_csv(PATH+filenames[i],header=None)
    data.append(df.iloc[0:N].mean()[0] - BEGIN)
ax.plot(data,color='r',marker='s',markersize=7,linewidth=2,markerfacecolor='none',markevery=1,linestyle='-')
ax.bar(x=[0,1,2,3,4],height=data,width=0.3,facecolor=colors[0],edgecolor="black",)


# ax2 = ax1.twinx()
# ax2.

plt.ylabel("FPS",labelFont)
plt.axhline(y=40 - BEGIN,color="black",ls='--')
plt.axhline(y=30 - BEGIN,color="black",ls='--')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks(np.arange(0,15,2))
ax.set_yticklabels(np.arange(28,43,2),fontsize=13)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1 client","10 clients","20 clients","30 clients","40 clients"],fontsize=13)
# plt.xticks(np.arange(75,800,150),xtickNames,rotation=0)
# plt.savefig("/home/yinlan/Desktop/fig12_scal.pdf",bbox_inches = 'tight')

# %%
filenames = ["glxgears_1.log_out","glxgears_10.log_out","glxgears_20.log_out","glxgears_30.log_out","glxgears_40.log_out"]
PATH = "fps/4_11/"
xtickNames = ["1","10","20","30","40"]

labelFont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 18
}

font2 = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 13
}
colors = ["#505050","r","#000000","#0065DD","#BBBBBB"]
N = 150
fig,ax = plt.subplots(1,1)
fig.set_figheight(4)
fig.set_figwidth(6)

data = []
BEGIN = 28
for i in range(0,5):
    df = pd.read_csv(PATH+filenames[i],header=None)
    data.append(df.iloc[0:N].mean()[0] - BEGIN)
# ax.plot(data,color='r',marker='s',markersize=7,linewidth=2,markerfacecolor='none',markevery=1,linestyle='-')
ax.bar(x=[0,1,2,3,4],height=data,width=0.3,facecolor=colors[0],edgecolor="black",label="FPS")
plt.legend(loc="upper left")
plt.axhline(y=40 - BEGIN,color="black",ls='--')
plt.axhline(y=30 - BEGIN,color="black",ls='--')
plt.ylabel("FPS",labelFont)

filenames2 = ["cpu_glxgears_10.log","cpu_glxgears_20.log","cpu_glxgears_30.log","cpu_glxgears_40.log"]
ax2 = ax.twinx()
data2 = []
data2.append(47.844)
PATH2 = "fps/4_11/cpu_scal/"
for i in range(0,4):
    df2 = pd.read_csv(PATH2+filenames2[i])
    data2.append(df2.mean()[0])
data2 = np.asarray(data2) / 4
ax2.plot(data2,color='r',marker='s',markersize=7,linewidth=2,markerfacecolor='none',markevery=1,linestyle='-',label="CPU Utilization")
ax2.set_ylabel("CPU Utilization(%)",labelFont)
ax2.set_yticks(np.arange(0,100,10))

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
ax.set_yticks(np.arange(0,15,2))
ax.set_yticklabels(np.arange(28,43,2),fontsize=13)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1 client","10 clients","20 clients","30 clients","40 clients"],fontsize=13)
plt.legend()
# plt.xticks(np.arange(75,800,150),xtickNames,rotation=0)
plt.savefig("/home/yinlan/Desktop/fig12_scal.pdf",bbox_inches = 'tight')

# %%
filenames = ["glxgears_1.log_out","glxgears_10.log_out","glxgears_20.log_out","glxgears_30.log_out","glxgears_40.log_out"]
PATH = "fps/4_11/"
xtickNames = ["1","10","20","30","40"]

labelFont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 18
}

font2 = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 13
}
colors = ["#505050","r","#000000","#0065DD","#BBBBBB"]
N = 150
fig,ax = plt.subplots(1,1)
fig.set_figheight(4)
fig.set_figwidth(6)

data = []
BEGIN = 28
for i in range(0,5):
    df = pd.read_csv(PATH+filenames[i],header=None)
    data.append(df.iloc[0:N].mean()[0] - BEGIN)
# ax.plot(data,color='r',marker='s',markersize=7,linewidth=2,markerfacecolor='none',markevery=1,linestyle='-')
ax.bar(x=[0,1,2,3,4],height=data,width=0.3,facecolor='black',edgecolor="black",label="FPS")
plt.axhline(y=40 - BEGIN,color="red",ls='--',linewidth=2)
plt.axhline(y=30 - BEGIN,color="red",ls='--')
plt.ylabel("FPS",labelFont)

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
ax.set_yticks(np.arange(0,13,2))
ax.set_yticklabels(np.arange(28,41,2),fontsize=13)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1 client","10 clients","20 clients","30 clients","40 clients"],fontsize=13)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc="upper left", bbox_to_anchor=(0.03, 0.80, 1.0, .12), frameon=True)
# plt.xticks(np.arange(75,800,150),xtickNames,rotation=0)
plt.savefig("/home/yinlan/Desktop/fig12_scal.pdf",bbox_inches = 'tight')

# %%
data2 = np.asarray(data2) / 2

# %%
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-eff1098d818d> in <module>
# ----> 1 data2
#
# NameError: name 'data2' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

fig,axarr = plt.subplots(2,4)
fig.set_figheight(8)
fig.set_figwidth(18)

titlefont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 22
}
labelfont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 20
}
 
xyticksfont = {
    'family' : 'Linux Libertine O',
    'weight' : 'normal',
    'size'   : 18
}

gData = pd.read_excel("all fps.xlsx", "gremote_withoutsleep")

def plot_line(ax,name:str):
    data50 = pd.read_excel('all fps.xlsx',name)
    data = (data50.iloc[-1] * 100)[:-1]
    ax.plot(data,color="#FF2600",markerfacecolor='none',marker='s',markersize=10,label="gRemote",linewidth=2)
    ind = [1,2,4,6,8,10]
    
    ax.plot(gData.loc[name] * 100,color="green",markerfacecolor='none',marker='s',markersize=10,label="gRemote without optimization",linewidth=2)
    
    data_awses = pd.read_excel('aws-fps-记录-new.xlsx',name)
    data_aws = data_awses.iloc[-1] * 100
    ax.plot(data_aws,color="#0065DD",markerfacecolor='none',marker='x',markersize=10,label="Amazon Elastic GPU",linewidth=2)
    ax.plot(data_aws,color="#0065DD",markerfacecolor='none',marker='+',markersize=10,label="",linewidth=2)
#     ax.plot(data_aws,color="k",markerfacecolor='none',marker='x',markersize=10,label="Amazon Elastic GPU",linewidth=2)
#     ax.plot(data_aws,color="k",markerfacecolor='none',marker='+',markersize=10,label="",linewidth=2)
    font = {'family' : 'Source Sans Pro',
        'weight' : 'normal',
        'size'   : 20
    }
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.set_title(name.capitalize(),titlefont)
    ax.set_ylabel('FPS(% of one client)',labelfont)
    ax.set_xlabel('Number of '+name.capitalize(),labelfont)
    ax.set_xticks([0,1,2,4,6,8,10])
    ax.set_xticklabels([0,1,2,4,6,8,10],fontsize=16)
    ax.set_yticks(np.arange(0,121,20))
    ax.set_yticklabels(np.arange(0,121,20),fontsize=16)
    ax.grid(ls="--",color="#B0B0B0")
#     ax.legend(fontsize=18,frameon=False)

program_names =  ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
for (ax,name) in zip(axarr.flat,program_names):
    plot_line(ax,name)
plt.tight_layout()
lgd = plt.legend(fontsize=23,frameon=False,bbox_to_anchor=(-3.95, 2.6, 4.4, 1.5), loc='lower left',ncol=3, mode="expand", borderaxespad=0.)
# plt.savefig("/home/yinlan/Desktop/fig7_gremote_aws.pdf",bbox_extra_artists=(lgd,),bbox_inches = 'tight')
# plt.savefig("/home/yinlan/Desktop/fig7_gremote_aws.pdf",bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a32c5ecd7e68> in <module>
#      59 program_names =  ['blender','dinoshade','scube','spot','stars','surfgrid','glxgears','drawelements']
#      60 for (ax,name) in zip(axarr.flat,program_names):
# ---> 61     plot_line(ax,name)
#      62 plt.tight_layout()
#      63 lgd = plt.legend(fontsize=23,frameon=False,bbox_to_anchor=(-3.95, 2.6, 4.4, 1.5), loc='lower left',ncol=3, mode="expand", borderaxespad=0.)
#
# <ipython-input-6-a32c5ecd7e68> in plot_line(ax, name)
#      30     data50 = pd.read_excel('all fps.xlsx',name)
#      31     data = (data50.iloc[-1] * 100)[:-1]
# ---> 32     ax.plot(data,color="#FF2600",markerfacecolor='none',marker='s',markersize=10,label="gRemote",linewidth=2)
#      33     ind = [1,2,4,6,8,10]
#      34
#
# ...

# %%
# ?plt.plot
